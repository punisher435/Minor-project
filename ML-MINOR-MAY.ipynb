# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = pd.read_csv(r"C:\Users\Prateek\Documents\StudentsPerformance.csv")

# %%
data1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data1.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#This means it has no null value

# %%
data1.columns=['gender', 'race', 'parental_level_of_education', 'lunch',
       'test_preparation_course', 'math_score', 'reading_score',
       'writing_score']

# %%
data1.head()
# Out:
#    gender     race parental_level_of_education         lunch  \
# 0  female  group B           bachelor's degree      standard
# 1  female  group C                some college      standard
# 2  female  group B             master's degree      standard
# 3    male  group A          associate's degree  free/reduced
# 4    male  group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data1.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data1[data1.gender=="male"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  482.000000     482.000000     482.000000
# mean    68.728216      65.473029      63.311203
# std     14.356277      13.931832      14.113832
# min     27.000000      23.000000      15.000000
# 25%     59.000000      56.000000      53.000000
# 50%     69.000000      66.000000      64.000000
# 75%     79.000000      75.000000      73.750000
# max    100.000000     100.000000     100.000000

# %%
data1[data1.gender=="female"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  518.000000     518.000000     518.000000
# mean    63.633205      72.608108      72.467181
# std     15.491453      14.378245      14.844842
# min      0.000000      17.000000      10.000000
# 25%     54.000000      63.250000      64.000000
# 50%     65.000000      73.000000      74.000000
# 75%     74.000000      83.000000      82.000000
# max    100.000000     100.000000     100.000000

# %%
print("Average and mode of math score of male")
print(data1[data1.gender=="male"].math_score.mean())
print(data1[data1.gender=="male"].math_score.mode())
print("Average and mode of math score of female")
print(data1[data1.gender=="female"].math_score.mean())
print(data1[data1.gender=="female"].math_score.mode())
# Out:
# Average and mode of math score of male
# 68.72821576763485
# 0    62
# dtype: int64
# Average and mode of math score of female
# 63.633204633204635
# 0    65
# dtype: int64

# %%
print("Average and mode of reading score of male")
print(data1[data1.gender=="male"].reading_score.mean())
print(data1[data1.gender=="male"].reading_score.mode())
print("Average and mode of reading score of female")
print(data1[data1.gender=="female"].reading_score.mean())
print(data1[data1.gender=="female"].reading_score.mode())
# Out:
# Average and mode of reading score of male
# 65.47302904564316
# 0    66
# 1    74
# dtype: int64
# Average and mode of reading score of female
# 72.60810810810811
# 0    72
# dtype: int64

# %%
print("Average and mode of writing score of male")
print(data1[data1.gender=="male"].writing_score.mean())
print(data1[data1.gender=="male"].writing_score.mode())
print("Average and mode of writing score of female")
print(data1[data1.gender=="female"].writing_score.mean())
print(data1[data1.gender=="female"].writing_score.mode())
# Out:
# Average and mode of writing score of male
# 63.31120331950208
# 0    68
# dtype: int64
# Average and mode of writing score of female
# 72.46718146718146
# 0    70
# dtype: int64

# %%
#average math score of male is greater than females
#average reading score of female is greater than males
#average writing score of female is greater than males

# %%
print(data1[data1.gender=="male"].math_score.min())
print(data1[data1.gender=="male"].math_score.max())
# Out:
# 27
# 100

# %%
print(data1[data1.gender=="female"].math_score.min())
print(data1[data1.gender=="female"].math_score.max())
# Out:
# 0
# 100

# %%
print(data1[data1.gender=="male"].reading_score.min())
print(data1[data1.gender=="male"].reading_score.max())
# Out:
# 23
# 100

# %%
print(data1[data1.gender=="female"].reading_score.min())
print(data1[data1.gender=="female"].reading_score.max())
# Out:
# 17
# 100

# %%
print(data1[data1.gender=="male"].writing_score.min())
print(data1[data1.gender=="male"].writing_score.max())
# Out:
# 15
# 100

# %%
print(data1[data1.gender=="female"].writing_score.min())
print(data1[data1.gender=="female"].writing_score.max())
# Out:
# 10
# 100

# %%
#both genders are able to score 100 out of 100
#male min score is greater than female

# %%
data1.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.countplot("gender",data=data1)

# %%
#females are slightly more than males

# %%
sns.distplot(data1[data1.gender=="male"].math_score,label="male",kde=True)
sns.distplot(data1[data1.gender=="female"].math_score,label="female",kde=True)
plt.legend(labels=["male","female"])
plt.ylabel("Probability density")
plt.show()

# %%
#this plot shows the probability density of math score of males and females
#the math score is more for males

# %%
sns.distplot(data1[data1.gender=="male"].reading_score,label="male",kde=True)
sns.distplot(data1[data1.gender=="female"].reading_score,label="female",kde=True)
plt.legend(labels=["male","female"])
plt.ylabel("Probability density")
plt.show()

# %%
#this plot shows the probability density of reading score of males and females
#the reading score for females is more for females

# %%
sns.distplot(data1[data1.gender=="male"].writing_score,label="male",kde=True)
sns.distplot(data1[data1.gender=="female"].writing_score,label="female",kde=True)
plt.legend(labels=["male","female"])
plt.ylabel("Probability density")
plt.show()

# %%
#this plot shows the probability density of writing score of males and females
#the writing score for females is more for females

# %%
sns.violinplot(data1[data1.gender=="male"].math_score)
plt.title("Male math score distribution")
# Out:
# Text(0.5, 1.0, 'Male math score distribution')

# %%
#values of male math score are more distributed in the range of 60-80

# %%
sns.violinplot(data1[data1.gender=="female"].math_score)
plt.title("female math score distribution")
# Out:
# Text(0.5, 1.0, 'female math score distribution')

# %%
#values of female math score are more distributed in the range of 50-75

# %%
sns.violinplot(data1[data1.gender=="male"].reading_score)
plt.title("Male reading score distribution")
# Out:
# Text(0.5, 1.0, 'Male reading score distribution')

# %%
#values of male reading score are more distributed in the range of 55-75

# %%
sns.violinplot(data1[data1.gender=="female"].reading_score)
plt.title("female reading score distribution")
# Out:
# Text(0.5, 1.0, 'female reading score distribution')

# %%
#values of female reading score are more distributed in the range of 65-85

# %%
sns.violinplot(data1[data1.gender=="male"].writing_score)
plt.title("male writing score distribution")
# Out:
# Text(0.5, 1.0, 'male writing score distribution')

# %%
#values of male writing score are more distributed in the range of 50-75

# %%
sns.violinplot(data1[data1.gender=="female"].writing_score)
plt.title("female writing score distribution")
# Out:
# Text(0.5, 1.0, 'female writing score distribution')

# %%
#values of female writing score are more distributed in the range of 62-82

# %%
data1.race.unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
data1[data1.race=="group A"].describe()
# Out:
#        math_score  reading_score  writing_score
# count   89.000000      89.000000      89.000000
# mean    61.629213      64.674157      62.674157
# std     14.523008      15.543762      15.468278
# min     28.000000      23.000000      19.000000
# 25%     51.000000      53.000000      51.000000
# 50%     61.000000      64.000000      62.000000
# 75%     71.000000      74.000000      73.000000
# max    100.000000     100.000000      97.000000

# %%
data1[data1.race=="group B"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  190.000000     190.000000     190.000000
# mean    63.452632      67.352632      65.600000
# std     15.468191      15.177499      15.625173
# min      8.000000      24.000000      15.000000
# 25%     54.000000      56.000000      55.250000
# 50%     63.000000      67.000000      67.000000
# 75%     74.000000      79.750000      78.000000
# max     97.000000      97.000000      96.000000

# %%
data1[data1.race=="group C"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  319.000000     319.000000     319.000000
# mean    64.463950      69.103448      67.827586
# std     14.852666      13.997033      14.983378
# min      0.000000      17.000000      10.000000
# 25%     55.000000      60.000000      57.000000
# 50%     65.000000      71.000000      68.000000
# 75%     74.000000      78.500000      79.000000
# max     98.000000     100.000000     100.000000

# %%
data1[data1.race=="group D"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  262.000000     262.000000     262.000000
# mean    67.362595      70.030534      70.145038
# std     13.769386      13.895306      14.367707
# min     26.000000      31.000000      32.000000
# 25%     59.000000      60.250000      61.000000
# 50%     69.000000      71.000000      72.000000
# 75%     77.000000      79.000000      80.000000
# max    100.000000     100.000000     100.000000

# %%
data1[data1.race=="group E"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  140.000000     140.000000     140.000000
# mean    73.821429      73.028571      71.407143
# std     15.534259      14.874024      15.113906
# min     30.000000      26.000000      22.000000
# 25%     64.750000      63.000000      62.000000
# 50%     74.500000      74.000000      72.000000
# 75%     85.000000      84.000000      80.250000
# max    100.000000     100.000000     100.000000

# %%
data1.race.value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race, dtype: int64

# %%
sns.countplot("race",data=data1)

# %%
#group c people have highest no. of people followed by group D while group A has the least

# %%
print("Gender distribution in Group A")
print(data1[data1.race=="group A"].gender.value_counts())
print("Gender distribution in Group B")
print(data1[data1.race=="group B"].gender.value_counts())
print("Gender distribution in Group C")
print(data1[data1.race=="group C"].gender.value_counts())
print("Gender distribution in Group D")
print(data1[data1.race=="group D"].gender.value_counts())
print("Gender distribution in Group E")
print(data1[data1.race=="group E"].gender.value_counts())
# Out:
# Gender distribution in Group A
# male      53
# female    36
# Name: gender, dtype: int64
# Gender distribution in Group B
# female    104
# male       86
# Name: gender, dtype: int64
# Gender distribution in Group C
# female    180
# male      139
# Name: gender, dtype: int64
# Gender distribution in Group D
# male      133
# female    129
# Name: gender, dtype: int64
# Gender distribution in Group E
# male      71
# female    69
# Name: gender, dtype: int64

# %%
#Group A has more number of males
#Group B has more number of females
#Group C has more number of females
#Group D has more number of males
#Group E has more number of males

# %%
print("Average and mode math score of group A")
print(data1[data1.race=="group A"].math_score.mean())
print(data1[data1.race=="group A"].math_score.mode())
print("Average and mode math score of group B")
print(data1[data1.race=="group B"].math_score.mean())
print(data1[data1.race=="group B"].math_score.mode())
print("Average and mode math score of group C")
print(data1[data1.race=="group C"].math_score.mean())
print(data1[data1.race=="group C"].math_score.mode())
print("Average and mode math score of group D")
print(data1[data1.race=="group D"].math_score.mean())
print(data1[data1.race=="group D"].math_score.mode())
print("Average and mode math score of group E")
print(data1[data1.race=="group E"].math_score.mean())
print(data1[data1.race=="group E"].math_score.mode())
# Out:
# Average and mode math score of group A
# 61.62921348314607
# 0    53
# 1    59
# 2    61
# dtype: int64
# Average and mode math score of group B
# 63.45263157894737
# 0    58
# 1    65
# dtype: int64
# Average and mode math score of group C
# 64.46394984326018
# 0    65
# dtype: int64
# Average and mode math score of group D
# 67.36259541984732
# 0    69
# dtype: int64
# Average and mode math score of group E
# 73.82142857142857
# 0    68
# 1    81
# 2    87
# dtype: int64

# %%
sns.distplot(data1[data1.race=="group A"].math_score,label="Group A",kde=True)
sns.distplot(data1[data1.race=="group B"].math_score,label="Group B",kde=True)
sns.distplot(data1[data1.race=="group C"].math_score,label="Group C",kde=True)
sns.distplot(data1[data1.race=="group D"].math_score,label="Group D",kde=True)
sns.distplot(data1[data1.race=="group E"].math_score,label="Group E",kde=True)
plt.legend(labels=["Group A","Group B","Group C","Group D","Group E"])
plt.ylabel("probability density")
# Out:
# Text(0, 0.5, 'probability density')

# %%
sns.boxplot(x="race",y="math_score",data=data1)

# %%
sns.boxplot(x="race",y="math_score",hue="gender",data=data1)

# %%
sns.violinplot(x="race",y="math_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="race",y="math_score",hue="gender",data=data1)

# %%
#group E males has better math score than other groups

# %%
print("Average and mode reading score of group A")
print(data1[data1.race=="group A"].reading_score.mean())
print(data1[data1.race=="group A"].reading_score.mode())
print("Average and mode reading score of group B")
print(data1[data1.race=="group B"].reading_score.mean())
print(data1[data1.race=="group B"].reading_score.mode())
print("Average and mode reading score of group C")
print(data1[data1.race=="group C"].reading_score.mean())
print(data1[data1.race=="group C"].reading_score.mode())
print("Average and mode reading score of group D")
print(data1[data1.race=="group D"].reading_score.mean())
print(data1[data1.race=="group D"].reading_score.mode())
print("Average and mode reading score of group E")
print(data1[data1.race=="group E"].reading_score.mean())
print(data1[data1.race=="group E"].reading_score.mode())
# Out:
# Average and mode reading score of group A
# 64.67415730337079
# 0    67
# dtype: int64
# Average and mode reading score of group B
# 67.35263157894737
# 0    65
# dtype: int64
# Average and mode reading score of group C
# 69.10344827586206
# 0    72
# dtype: int64
# Average and mode reading score of group D
# 70.03053435114504
# 0    70
# 1    74
# dtype: int64
# Average and mode reading score of group E
# 73.02857142857142
# 0    74
# 1    76
# dtype: int64

# %%
sns.distplot(data1[data1.race=="group A"].reading_score,label="Group A",kde=True)
sns.distplot(data1[data1.race=="group B"].reading_score,label="Group B",kde=True)
sns.distplot(data1[data1.race=="group C"].reading_score,label="Group C",kde=True)
sns.distplot(data1[data1.race=="group D"].reading_score,label="Group D",kde=True)
sns.distplot(data1[data1.race=="group E"].reading_score,label="Group E",kde=True)
plt.legend(labels=["Group A","Group B","Group C","Group D","Group E"])
plt.ylabel("probability density")
# Out:
# Text(0, 0.5, 'probability density')

# %%
sns.boxplot(x="race",y="reading_score",data=data1)

# %%
sns.boxplot(x="race",y="reading_score",hue="gender",data=data1)

# %%
sns.violinplot(x="race",y="reading_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="race",y="reading_score",hue="gender",data=data1)

# %%
#group E females has better reading score than other groups

# %%
print("Average and mode writing score of group A")
print(data1[data1.race=="group A"].writing_score.mean())
print(data1[data1.race=="group A"].writing_score.mode())
print("Average and mode writing score of group B")
print(data1[data1.race=="group B"].writing_score.mean())
print(data1[data1.race=="group B"].writing_score.mode())
print("Average and mode writing score of group C")
print(data1[data1.race=="group C"].writing_score.mean())
print(data1[data1.race=="group C"].writing_score.mode())
print("Average and mode writing score of group D")
print(data1[data1.race=="group D"].writing_score.mean())
print(data1[data1.race=="group D"].writing_score.mode())
print("Average and mode writing score of group E")
print(data1[data1.race=="group E"].writing_score.mean())
print(data1[data1.race=="group E"].writing_score.mode())
# Out:
# Average and mode writing score of group A
# 62.674157303370784
# 0    43
# 1    64
# dtype: int64
# Average and mode writing score of group B
# 65.6
# 0    68
# dtype: int64
# Average and mode writing score of group C
# 67.82758620689656
# 0    74
# dtype: int64
# Average and mode writing score of group D
# 70.14503816793894
# 0    74
# dtype: int64
# Average and mode writing score of group E
# 71.40714285714286
# 0    70
# dtype: int64

# %%
sns.distplot(data1[data1.race=="group A"].writing_score,label="Group A",kde=True)
sns.distplot(data1[data1.race=="group B"].writing_score,label="Group B",kde=True)
sns.distplot(data1[data1.race=="group C"].writing_score,label="Group C",kde=True)
sns.distplot(data1[data1.race=="group D"].writing_score,label="Group D",kde=True)
sns.distplot(data1[data1.race=="group E"].writing_score,label="Group E",kde=True)
plt.legend(labels=["Group A","Group B","Group C","Group D","Group E"])
plt.ylabel("probability density")
# Out:
# Text(0, 0.5, 'probability density')

# %%
sns.boxplot(x="race",y="writing_score",data=data1)

# %%
sns.boxplot(x="race",y="writing_score",hue="gender",data=data1)

# %%
sns.violinplot(x="race",y="writing_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="race",y="writing_score",hue="gender",data=data1)

# %%
#group E females has better writing score than other groups

# %%
data1.parental_level_of_education.unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
data1[data1.parental_level_of_education=="bachelor's degree"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  118.000000      118.00000     118.000000
# mean    69.389831       73.00000      73.381356
# std     14.943789       14.28525      14.728262
# min     29.000000       41.00000      38.000000
# 25%     61.000000       63.00000      62.500000
# 50%     68.000000       73.00000      74.000000
# 75%     79.000000       82.75000      83.000000
# max    100.000000      100.00000     100.000000

# %%
data1[data1.parental_level_of_education=="some college"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  226.000000     226.000000     226.000000
# mean    67.128319      69.460177      68.840708
# std     14.312897      14.057049      15.012331
# min     19.000000      23.000000      19.000000
# 25%     59.000000      60.000000      60.000000
# 50%     67.500000      70.500000      70.000000
# 75%     76.000000      79.750000      79.000000
# max    100.000000     100.000000      99.000000

# %%
data1[data1.parental_level_of_education=="master's degree"].describe()
# Out:
#        math_score  reading_score  writing_score
# count   59.000000      59.000000      59.000000
# mean    69.745763      75.372881      75.677966
# std     15.153915      13.775163      13.730711
# min     40.000000      42.000000      46.000000
# 25%     55.500000      65.500000      67.000000
# 50%     73.000000      76.000000      75.000000
# 75%     81.000000      84.500000      85.000000
# max     95.000000     100.000000     100.000000

# %%
data1[data1.parental_level_of_education=="associate's degree"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  222.000000     222.000000     222.000000
# mean    67.882883      70.927928      69.896396
# std     15.112093      13.868948      14.311122
# min     26.000000      31.000000      35.000000
# 25%     57.000000      61.000000      58.000000
# 50%     67.000000      72.500000      70.500000
# 75%     80.000000      81.000000      80.000000
# max    100.000000     100.000000     100.000000

# %%
data1[data1.parental_level_of_education=="high school"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  196.000000     196.000000     196.000000
# mean    62.137755      64.704082      62.448980
# std     14.539651      14.132130      14.085907
# min      8.000000      24.000000      15.000000
# 25%     53.750000      54.000000      52.000000
# 50%     63.000000      66.000000      64.000000
# 75%     72.000000      74.250000      73.000000
# max     99.000000      99.000000     100.000000

# %%
data1[data1.parental_level_of_education=="some high school"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  179.000000     179.000000     179.000000
# mean    63.497207      66.938547      64.888268
# std     15.927989      15.479295      15.736197
# min      0.000000      17.000000      10.000000
# 25%     53.000000      56.500000      54.000000
# 50%     65.000000      67.000000      66.000000
# 75%     74.000000      79.000000      77.000000
# max     97.000000     100.000000     100.000000

# %%
data1.parental_level_of_education.value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental_level_of_education, dtype: int64

# %%
sns.countplot("parental_level_of_education",data=data1)

# %%
#there are more parents with 'some college',"associate's degree", 'high school', 'some high school' level of education
#master's degree level of education are the least

# %%
print(" parents of students with male gender :")
print(data1[data1.gender=="male"].parental_level_of_education.value_counts())
print(" parents of students with female gende :")
print(data1[data1.gender=="female"].parental_level_of_education.value_counts())
# Out:
#  parents of students with male gender :
# some college          108
# associate's degree    106
# high school           102
# some high school       88
# bachelor's degree      55
# master's degree        23
# Name: parental_level_of_education, dtype: int64
#  parents of students with female gende :
# some college          118
# associate's degree    116
# high school            94
# some high school       91
# bachelor's degree      63
# master's degree        36
# Name: parental_level_of_education, dtype: int64

# %%
print(" parents of students with group A :")
print(data1[data1.race=="group A"].parental_level_of_education.value_counts())
print(" parents of students with group B :")
print(data1[data1.race=="group B"].parental_level_of_education.value_counts())
print(" parents of students with group C :")
print(data1[data1.race=="group C"].parental_level_of_education.value_counts())
print(" parents of students with group D :")
print(data1[data1.race=="group D"].parental_level_of_education.value_counts())
print(" parents of students with group E :")
print(data1[data1.race=="group E"].parental_level_of_education.value_counts())
# Out:
#  parents of students with group A :
# some high school      24
# high school           18
# some college          18
# associate's degree    14
# bachelor's degree     12
# master's degree        3
# Name: parental_level_of_education, dtype: int64
#  parents of students with group B :
# high school           48
# associate's degree    41
# some high school      38
# some college          37
# bachelor's degree     20
# master's degree        6
# Name: parental_level_of_education, dtype: int64
#  parents of students with group C :
# associate's degree    78
# some college          69
# high school           64
# some high school      49
# bachelor's degree     40
# master's degree       19
# Name: parental_level_of_education, dtype: int64
#  parents of students with group D :
# some college          67
# some high school      50
# associate's degree    50
# high school           44
# bachelor's degree     28
# master's degree       23
# Name: parental_level_of_education, dtype: int64
# ...

# %%
print("The average and the mode of math score of the parental level of education of bachelor's degree are")
print(data1[data1.parental_level_of_education=="bachelor's degree"].math_score.mean())
print(data1[data1.parental_level_of_education=="bachelor's degree"].math_score.mode())
print("The average and the mode of math score of the parental level of education of some college are")
print(data1[data1.parental_level_of_education=="some college"].math_score.mean())
print(data1[data1.parental_level_of_education=="some college"].math_score.mode())
print("The average and the mode of math score of the parental level of education of master's degree are")
print(data1[data1.parental_level_of_education=="master's degree"].math_score.mean())
print(data1[data1.parental_level_of_education=="master's degree"].math_score.mode())
print("The average and the mode of math score of the parental level of education of associate's degree are")
print(data1[data1.parental_level_of_education=="associate's degree"].math_score.mean())
print(data1[data1.parental_level_of_education=="associate's degree"].math_score.mode())
print("The average and the mode of math score of the parental level of education of high school are")
print(data1[data1.parental_level_of_education=="high school"].math_score.mean())
print(data1[data1.parental_level_of_education=="high school"].math_score.mode())
print("The average and the mode of math score of the parental level of education of some high school are")
print(data1[data1.parental_level_of_education=="some high school"].math_score.mean())
print(data1[data1.parental_level_of_education=="some high school"].math_score.mode())
# Out:
# The average and the mode of math score of the parental level of education of bachelor's degree are
# 69.38983050847457
# 0    63
# 1    65
# 2    66
# dtype: int64
# The average and the mode of math score of the parental level of education of some college are
# 67.1283185840708
# 0    69
# dtype: int64
# The average and the mode of math score of the parental level of education of master's degree are
# 69.7457627118644
# 0    79
# 1    81
# dtype: int64
# The average and the mode of math score of the parental level of education of associate's degree are
# 67.88288288288288
# 0    65
# dtype: int64
# The average and the mode of math score of the parental level of education of high school are
# 62.13775510204081
# 0    57
# 1    66
# dtype: int64
# The average and the mode of math score of the parental level of education of some high school are
# 63.497206703910614
# 0    59
# 1    65
# dtype: int64

# %%
sns.distplot(data1[data1.parental_level_of_education=="bachelor's degree"].math_score,label="bachelor's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="some college"].math_score,label="some college",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="master's degree"].math_score,label="master's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="associate's degree"].math_score,label="associate's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="high school"].math_score,label="high school",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="some high school"].math_score,label="some high school",kde=True)
plt.legend(labels=["bachelor's degree", "some college", "master's degree",
       "associate's degree", 'high school', 'some high school'])
plt.ylabel("Probability density")
plt.show()

# %%
sns.boxplot(x="parental_level_of_education",y="math_score",data=data1)

# %%
sns.boxplot(x="parental_level_of_education",y="math_score",hue="gender",data=data1)

# %%
sns.boxplot(x="parental_level_of_education",y="math_score",hue="race",data=data1)

# %%
sns.violinplot(x="parental_level_of_education",y="math_score",hue="gender",data=data1)

# %%
sns.violinplot(x="parental_level_of_education",y="math_score",hue="race",data=data1)

# %%
sns.scatterplot(x="parental_level_of_education",y="math_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="parental_level_of_education",y="math_score",hue="race",data=data1)

# %%
# male students with parental level of education as master's degree and bachelor's degree and of group E have better math score
#some students in group E performed exceptionally well in math test of parental level of education as some school and high school

# %%
print("The average and the mode of reading score of the parental level of education of bachelor's degree are")
print(data1[data1.parental_level_of_education=="bachelor's degree"].reading_score.mean())
print(data1[data1.parental_level_of_education=="bachelor's degree"].reading_score.mode())
print("The average and the mode of reading score of the parental level of education of some college are")
print(data1[data1.parental_level_of_education=="some college"].reading_score.mean())
print(data1[data1.parental_level_of_education=="some college"].reading_score.mode())
print("The average and the mode of reading score of the parental level of education of master's degree are")
print(data1[data1.parental_level_of_education=="master's degree"].reading_score.mean())
print(data1[data1.parental_level_of_education=="master's degree"].reading_score.mode())
print("The average and the mode of reading score of the parental level of education of associate's degree are")
print(data1[data1.parental_level_of_education=="associate's degree"].reading_score.mean())
print(data1[data1.parental_level_of_education=="associate's degree"].reading_score.mode())
print("The average and the mode of reading score of the parental level of education of high school are")
print(data1[data1.parental_level_of_education=="high school"].reading_score.mean())
print(data1[data1.parental_level_of_education=="high school"].reading_score.mode())
print("The average and the mode of reading score of the parental level of education of some high school are")
print(data1[data1.parental_level_of_education=="some high school"].reading_score.mean())
print(data1[data1.parental_level_of_education=="some high school"].reading_score.mode())
# Out:
# The average and the mode of reading score of the parental level of education of bachelor's degree are
# 73.0
# 0    100
# dtype: int64
# The average and the mode of reading score of the parental level of education of some college are
# 69.46017699115045
# 0    64
# 1    74
# 2    78
# dtype: int64
# The average and the mode of reading score of the parental level of education of master's degree are
# 75.37288135593221
# 0    81
# dtype: int64
# The average and the mode of reading score of the parental level of education of associate's degree are
# 70.92792792792793
# 0    76
# dtype: int64
# The average and the mode of reading score of the parental level of education of high school are
# 64.70408163265306
# 0    52
# 1    72
# dtype: int64
# The average and the mode of reading score of the parental level of education of some high school are
# 66.93854748603351
# 0    67
# 1    84
# dtype: int64

# %%
sns.distplot(data1[data1.parental_level_of_education=="bachelor's degree"].reading_score,label="bachelor's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="some college"].reading_score,label="some college",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="master's degree"].reading_score,label="master's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="associate's degree"].reading_score,label="associate's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="high school"].reading_score,label="high school",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="some high school"].reading_score,label="some high school",kde=True)
plt.legend(labels=["bachelor's degree", "some college", "master's degree",
       "associate's degree", 'high school', 'some high school'])
plt.ylabel("Probability density")
plt.show()

# %%
sns.boxplot(x="parental_level_of_education",y="reading_score",data=data1)

# %%
sns.boxplot(x="parental_level_of_education",y="reading_score",hue="gender",data=data1)

# %%
sns.boxplot(x="parental_level_of_education",y="reading_score",hue="race",data=data1)

# %%
sns.violinplot(x="parental_level_of_education",y="reading_score",hue="gender",data=data1)

# %%
sns.violinplot(x="parental_level_of_education",y="math_score",hue="race",data=data1)

# %%
sns.scatterplot(x="parental_level_of_education",y="reading_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="parental_level_of_education",y="reading_score",hue="race",data=data1)

# %%
# female students with parental level of education as master's degree and bachelor's degree and have better reading score
#some female students in group E and group B performed exceptionally well in reading test of parental level of education as master's degree

# %%
print("The average and the mode of writing score of the parental level of education of bachelor's degree are")
print(data1[data1.parental_level_of_education=="bachelor's degree"].writing_score.mean())
print(data1[data1.parental_level_of_education=="bachelor's degree"].writing_score.mode())
print("The average and the mode of writing score of the parental level of education of some college are")
print(data1[data1.parental_level_of_education=="some college"].writing_score.mean())
print(data1[data1.parental_level_of_education=="some college"].writing_score.mode())
print("The average and the mode of writing score of the parental level of education of master's degree are")
print(data1[data1.parental_level_of_education=="master's degree"].writing_score.mean())
print(data1[data1.parental_level_of_education=="master's degree"].writing_score.mode())
print("The average and the mode of writing score of the parental level of education of associate's degree are")
print(data1[data1.parental_level_of_education=="associate's degree"].writing_score.mean())
print(data1[data1.parental_level_of_education=="associate's degree"].writing_score.mode())
print("The average and the mode of writing score of the parental level of education of high school are")
print(data1[data1.parental_level_of_education=="high school"].writing_score.mean())
print(data1[data1.parental_level_of_education=="high school"].writing_score.mode())
print("The average and the mode of writing score of the parental level of education of some high school are")
print(data1[data1.parental_level_of_education=="some high school"].writing_score.mean())
print(data1[data1.parental_level_of_education=="some high school"].writing_score.mode())
# Out:
# The average and the mode of writing score of the parental level of education of bachelor's degree are
# 73.38135593220339
# 0     81
# 1    100
# dtype: int64
# The average and the mode of writing score of the parental level of education of some college are
# 68.84070796460178
# 0    70
# dtype: int64
# The average and the mode of writing score of the parental level of education of master's degree are
# 75.67796610169492
# 0     75
# 1     84
# 2    100
# dtype: int64
# The average and the mode of writing score of the parental level of education of associate's degree are
# 69.8963963963964
# 0    73
# dtype: int64
# The average and the mode of writing score of the parental level of education of high school are
# 62.44897959183673
# 0    68
# dtype: int64
# The average and the mode of writing score of the parental level of education of some high school are
# 64.88826815642459
# 0    78
# dtype: int64

# %%
sns.distplot(data1[data1.parental_level_of_education=="bachelor's degree"].writing_score,label="bachelor's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="some college"].writing_score,label="some college",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="master's degree"].writing_score,label="master's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="associate's degree"].writing_score,label="associate's degree",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="high school"].writing_score,label="high school",kde=True)
sns.distplot(data1[data1.parental_level_of_education=="some high school"].writing_score,label="some high school",kde=True)
plt.legend(labels=["bachelor's degree", "some college", "master's degree",
       "associate's degree", 'high school', 'some high school'])
plt.show()

# %%
sns.boxplot(x="parental_level_of_education",y="writing_score",data=data1)

# %%
sns.boxplot(x="parental_level_of_education",y="writing_score",hue="gender",data=data1)

# %%
sns.boxplot(x="parental_level_of_education",y="writing_score",hue="race",data=data1)

# %%
sns.violinplot(x="parental_level_of_education",y="writing_score",hue="gender",data=data1)

# %%
sns.violinplot(x="parental_level_of_education",y="writing_score",hue="race",data=data1)

# %%
sns.scatterplot(x="parental_level_of_education",y="writing_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="parental_level_of_education",y="writing_score",hue="gender",data=data1)

# %%
# female students with parental level of education as master's degree and bachelor's degree have better writing score

# %%
data1.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
data1[data1.lunch=="standard"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
data1[data1.lunch=="free/reduced"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
data1.lunch.value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
sns.countplot("lunch",data=data1)

# %%
#students with standard type of lunch are double of the students with free/reduced type of lunch

# %%
print("students lunch distribution on the basis of male gender")
print(data1[data1.gender=="male"].lunch.value_counts())
print("students lunch distribution on the basis of female gender")
print(data1[data1.gender=="female"].lunch.value_counts())
# Out:
# students lunch distribution on the basis of male gender
# standard        316
# free/reduced    166
# Name: lunch, dtype: int64
# students lunch distribution on the basis of female gender
# standard        329
# free/reduced    189
# Name: lunch, dtype: int64

# %%
print("students lunch distribution on group A")
print(data1[data1.race=="group A"].lunch.value_counts())
print("students lunch distribution on group B")
print(data1[data1.race=="group B"].lunch.value_counts())
print("students lunch distribution on group C")
print(data1[data1.race=="group C"].lunch.value_counts())
print("students lunch distribution on group D")
print(data1[data1.race=="group D"].lunch.value_counts())
print("students lunch distribution on group E")
print(data1[data1.race=="group E"].lunch.value_counts())
# Out:
# students lunch distribution on group A
# standard        53
# free/reduced    36
# Name: lunch, dtype: int64
# students lunch distribution on group B
# standard        121
# free/reduced     69
# Name: lunch, dtype: int64
# students lunch distribution on group C
# standard        205
# free/reduced    114
# Name: lunch, dtype: int64
# students lunch distribution on group D
# standard        167
# free/reduced     95
# Name: lunch, dtype: int64
# students lunch distribution on group E
# standard        99
# free/reduced    41
# Name: lunch, dtype: int64

# %%
print("students lunch distribution bachelor's degree")
print(data1[data1.parental_level_of_education=="bachelor's degree"].lunch.value_counts())
print("students lunch distribution some college")
print(data1[data1.parental_level_of_education=="some college"].lunch.value_counts())
print("students lunch distribution master's degree")
print(data1[data1.parental_level_of_education=="master's degree"].lunch.value_counts())
print("students lunch distribution associate's degree")
print(data1[data1.parental_level_of_education=="associate's degree"].lunch.value_counts())
print("students lunch distribution high school")
print(data1[data1.parental_level_of_education=="high school"].lunch.value_counts())
print("students lunch distribution some high school")
print(data1[data1.parental_level_of_education=="some high school"].lunch.value_counts())
# Out:
# students lunch distribution bachelor's degree
# standard        74
# free/reduced    44
# Name: lunch, dtype: int64
# students lunch distribution some college
# standard        147
# free/reduced     79
# Name: lunch, dtype: int64
# students lunch distribution master's degree
# standard        35
# free/reduced    24
# Name: lunch, dtype: int64
# students lunch distribution associate's degree
# standard        145
# free/reduced     77
# Name: lunch, dtype: int64
# students lunch distribution high school
# standard        126
# free/reduced     70
# Name: lunch, dtype: int64
# students lunch distribution some high school
# standard        118
# free/reduced     61
# Name: lunch, dtype: int64

# %%
print("The average and mode of math score of standard type lunch are :")
print(data1[data1.lunch=="standard"].math_score.mean())
print(data1[data1.lunch=="standard"].math_score.mode())
print("The average and mode of math score of free/reduced type lunch are :")
print(data1[data1.lunch=="free/reduced"].math_score.mean())
print(data1[data1.lunch=="free/reduced"].math_score.mode())
# Out:
# The average and mode of math score of standard type lunch are :
# 70.03410852713178
# 0    69
# dtype: int64
# The average and mode of math score of free/reduced type lunch are :
# 58.92112676056338
# 0    61
# dtype: int64

# %%
sns.distplot(data1[data1.lunch=="standard"].math_score,label="standard",kde=True)
sns.distplot(data1[data1.lunch=="free/reduced"].math_score,label="free/reduced",kde=True)
plt.title("distribution of math score on different lunch type")
plt.legend(labels=['standard','free/reduced'])
plt.show()

# %%
sns.boxplot(x="lunch",y="math_score",data=data1)

# %%
sns.boxplot(x="lunch",y="math_score",hue="gender",data=data1)

# %%
sns.violinplot(x="lunch",y="math_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="lunch",y="math_score",hue="gender",data=data1)

# %%
sns.boxplot(x="lunch",y="math_score",hue="race",data=data1)

# %%
sns.violinplot(x="lunch",y="math_score",hue="race",data=data1)

# %%
sns.scatterplot(x="lunch",y="math_score",hue="race",data=data1)

# %%
sns.boxplot(x="lunch",y="math_score",hue="parental_level_of_education",data=data1)

# %%
sns.violinplot(x="lunch",y="math_score",hue="parental_level_of_education",data=data1)

# %%
sns.scatterplot(x="lunch",y="math_score",hue="parental_level_of_education",data=data1)

# %%
# male students with standard type of lunch, of group E and master's degree level of educstion seem to have scored better in math test than everyone 
#some female student performed exceptionally well in math test free /reduced type of lunch

# %%
print("The average and mode of reading score of standard type lunch are :")
print(data1[data1.lunch=="standard"].reading_score.mean())
print(data1[data1.lunch=="standard"].reading_score.mode())
print("The average and mode of reading score of free/reduced type lunch are :")
print(data1[data1.lunch=="free/reduced"].reading_score.mean())
print(data1[data1.lunch=="free/reduced"].reading_score.mode())
# Out:
# The average and mode of reading score of standard type lunch are :
# 71.65426356589147
# 0    64
# dtype: int64
# The average and mode of reading score of free/reduced type lunch are :
# 64.65352112676057
# 0    58
# dtype: int64

# %%
sns.distplot(data1[data1.lunch=="standard"].reading_score,label="standard",kde=True)
sns.distplot(data1[data1.lunch=="free/reduced"].reading_score,label="standard",kde=True)
plt.title("distribution of reading score on different lunch type")
plt.legend(labels=['standard','free/reduced'])
plt.show()

# %%
sns.boxplot(x="lunch",y="reading_score",data=data1)

# %%
sns.boxplot(x="lunch",y="reading_score",hue="gender",data=data1)

# %%
sns.violinplot(x="lunch",y="reading_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="lunch",y="reading_score",hue="gender",data=data1)

# %%
sns.boxplot(x="lunch",y="reading_score",hue="race",data=data1)

# %%
sns.violinplot(x="lunch",y="reading_score",hue="race",data=data1)

# %%
sns.scatterplot(x="lunch",y="reading_score",hue="race",data=data1)

# %%
sns.boxplot(x="lunch",y="reading_score",hue="parental_level_of_education",data=data1)

# %%
sns.violinplot(x="lunch",y="reading_score",hue="parental_level_of_education",data=data1)

# %%
sns.scatterplot(x="lunch",y="reading_score",hue="parental_level_of_education",data=data1)

# %%
#females of standard type of lunch, group E and master's degree level of education have performed better than anyone in reading test

# %%
print("The average and mode of writing score of standard type lunch are :")
print(data1[data1.lunch=="standard"].writing_score.mean())
print(data1[data1.lunch=="standard"].writing_score.mode())
print("The average and mode of writing score of free/reduced type lunch are :")
print(data1[data1.lunch=="free/reduced"].writing_score.mean())
print(data1[data1.lunch=="free/reduced"].writing_score.mode())
# Out:
# The average and mode of writing score of standard type lunch are :
# 70.8232558139535
# 0    74
# dtype: int64
# The average and mode of writing score of free/reduced type lunch are :
# 63.02253521126761
# 0    54
# dtype: int64

# %%
sns.distplot(data1[data1.lunch=="standard"].writing_score,label="standard",kde=True)
sns.distplot(data1[data1.lunch=="free/reduced"].writing_score,label="free/reduced",kde=True)
plt.title("distribution of writing score on different lunch type")
plt.legend(labels=['standard','free/reduced'])
plt.show()

# %%
sns.boxplot(x="lunch",y="writing_score",data=data1)

# %%
sns.boxplot(x="lunch",y="writing_score",hue="gender",data=data1)

# %%
sns.violinplot(x="lunch",y="writing_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="lunch",y="writing_score",hue="gender",data=data1)

# %%
sns.boxplot(x="lunch",y="writing_score",hue="race",data=data1)

# %%
sns.violinplot(x="lunch",y="writing_score",hue="race",data=data1)

# %%
sns.scatterplot(x="lunch",y="writing_score",hue="race",data=data1)

# %%
sns.boxplot(x="lunch",y="writing_score",hue="parental_level_of_education",data=data1)

# %%
sns.violinplot(x="lunch",y="writing_score",hue="parental_level_of_education",data=data1)

# %%
sns.scatterplot(x="lunch",y="writing_score",hue="parental_level_of_education",data=data1)

# %%
#females of standard type of lunch, group E and master's degree level of education have performed better than anyone

# %%
data1.test_preparation_course.unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
data1[data1.test_preparation_course=="none"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  642.000000     642.000000     642.000000
# mean    64.077882      66.534268      64.504673
# std     15.192376      14.463885      14.999661
# min      0.000000      17.000000      10.000000
# 25%     54.000000      57.000000      54.000000
# 50%     64.000000      67.000000      65.000000
# 75%     74.750000      76.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
data1[data1.test_preparation_course=="completed"].describe()
# Out:
#        math_score  reading_score  writing_score
# count  358.000000     358.000000     358.000000
# mean    69.695531      73.893855      74.418994
# std     14.444699      13.638384      13.375335
# min     23.000000      37.000000      36.000000
# 25%     60.000000      65.000000      66.000000
# 50%     69.000000      75.000000      76.000000
# 75%     79.000000      84.000000      83.000000
# max    100.000000     100.000000     100.000000

# %%
data1.test_preparation_course.value_counts()
# Out:
# none         642
# completed    358
# Name: test_preparation_course, dtype: int64

# %%
sns.countplot(data1.test_preparation_course)

# %%
#students with no test preparation course are almost twice that of students who have completed the test preparation course

# %%
print("distribution of students who have completed test preparation course in male gender")
print(data1[data1.gender=="male"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course in female gender")
print(data1[data1.gender=="female"].test_preparation_course.value_counts())
# Out:
# distribution of students who have completed test preparation course in male gender
# none         308
# completed    174
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course in female gender
# none         334
# completed    184
# Name: test_preparation_course, dtype: int64

# %%
print("distribution of students who have completed test preparation course in group A")
print(data1[data1.race=="group A"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course in group B")
print(data1[data1.race=="group B"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course in group C")
print(data1[data1.race=="group C"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course in group D")
print(data1[data1.race=="group D"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course in group E")
print(data1[data1.race=="group E"].test_preparation_course.value_counts())
# Out:
# distribution of students who have completed test preparation course in group A
# none         58
# completed    31
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course in group B
# none         122
# completed     68
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course in group C
# none         202
# completed    117
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course in group D
# none         180
# completed     82
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course in group E
# none         80
# completed    60
# Name: test_preparation_course, dtype: int64

# %%
print("distribution of students who have completed test preparation course of bachelor's degree parental level of education")
print(data1[data1.parental_level_of_education=="bachelor's degree"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course of some college parental level of education")
print(data1[data1.parental_level_of_education=="some college"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course of master's degree parental level of education")
print(data1[data1.parental_level_of_education=="master's degree"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course of associate's degree parental level of education")
print(data1[data1.parental_level_of_education=="associate's degree"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course of high school parental level of education")
print(data1[data1.parental_level_of_education=="high school"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course of some high school parental level of education")
print(data1[data1.parental_level_of_education=="some high school"].test_preparation_course.value_counts())
# Out:
# distribution of students who have completed test preparation course of bachelor's degree parental level of education
# none         72
# completed    46
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course of some college parental level of education
# none         149
# completed     77
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course of master's degree parental level of education
# none         39
# completed    20
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course of associate's degree parental level of education
# none         140
# completed     82
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course of high school parental level of education
# none         140
# completed     56
# Name: test_preparation_course, dtype: int64
# ...

# %%
print("distribution of students who have completed test preparation course of standard lunch type")
print(data1[data1.lunch=="standard"].test_preparation_course.value_counts())
print("distribution of students who have completed test preparation course of free/reduced lunch type")
print(data1[data1.lunch=="free/reduced"].test_preparation_course.value_counts())
# Out:
# distribution of students who have completed test preparation course of standard lunch type
# none         418
# completed    227
# Name: test_preparation_course, dtype: int64
# distribution of students who have completed test preparation course of free/reduced lunch type
# none         224
# completed    131
# Name: test_preparation_course, dtype: int64

# %%
print("the average and mode of the math score of the none test preparation type students")
print(data1[data1.test_preparation_course=="none"].math_score.mean())
print(data1[data1.test_preparation_course=="none"].math_score.mode())
print("the average and mode of the math score of the complete test preparation type students")
print(data1[data1.test_preparation_course=="completed"].math_score.mean())
print(data1[data1.test_preparation_course=="completed"].math_score.mode())
# Out:
# the average and mode of the math score of the none test preparation type students
# 64.0778816199377
# 0    62
# dtype: int64
# the average and mode of the math score of the complete test preparation type students
# 69.69553072625699
# 0    65
# dtype: int64

# %%
sns.distplot(data1[data1.test_preparation_course=="none"].math_score,label="none",kde=True)
sns.distplot(data1[data1.test_preparation_course=="completed"].math_score,label="completed",kde=True)
plt.title("distribution of the students math score on the basis ofthort test preparation course")
plt.legend(labels=["none","completed"])
plt.show()

# %%
sns.boxplot(x="test_preparation_course",y="math_score",data=data1)

# %%
#students who have completed test prearation course have scored slightly higher in math test than students who have not done any course

# %%
sns.boxplot(x="test_preparation_course",y="math_score",hue="gender",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="math_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="math_score",hue="gender",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="math_score",hue="race",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="math_score",hue="race",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="math_score",hue="race",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="math_score",hue="parental_level_of_education",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="math_score",hue="parental_level_of_education",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="math_score",hue="parental_level_of_education",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="math_score",hue="lunch",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="math_score",hue="lunch",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="math_score",hue="lunch",data=data1)

# %%
#male students of grouo E and bachelors degree parental level of education and standard lunch have scored better in math test

# %%
print("the average and mode of the reading score of the none test preparation type students")
print(data1[data1.test_preparation_course=="none"].reading_score.mean())
print(data1[data1.test_preparation_course=="none"].reading_score.mode())
print("the average and mode of the reading score of the complete test preparation type students")
print(data1[data1.test_preparation_course=="completed"].reading_score.mean())
print(data1[data1.test_preparation_course=="completed"].reading_score.mode())
# Out:
# the average and mode of the reading score of the none test preparation type students
# 66.53426791277259
# 0    72
# dtype: int64
# the average and mode of the reading score of the complete test preparation type students
# 73.89385474860335
# 0    74
# dtype: int64

# %%
sns.distplot(data1[data1.test_preparation_course=="none"].reading_score,label="none",kde=True)
sns.distplot(data1[data1.test_preparation_course=="completed"].reading_score,label="completed",kde=True)
plt.title("distribution of the students reading score on the basis ofthort test preparation course")
plt.legend(labels=["none","completed"])
plt.show()

# %%
sns.boxplot(x="test_preparation_course",y="reading_score",data=data1)

# %%
#students who have completed test prearation course have scored slightly higher in reading test than students who have not done any course

# %%
sns.boxplot(x="test_preparation_course",y="reading_score",hue="gender",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="reading_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="reading_score",hue="gender",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="reading_score",hue="race",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="reading_score",hue="race",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="reading_score",hue="race",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="reading_score",hue="parental_level_of_education",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="reading_score",hue="parental_level_of_education",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="reading_score",hue="parental_level_of_education",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="reading_score",hue="lunch",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="reading_score",hue="lunch",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="reading_score",hue="lunch",data=data1)

# %%
#female students of grouo E and master's degree parental level of education and standard lunch have scored better in reading test

# %%
print("the average and mode of the writing score of the none test preparation type students")
print(data1[data1.test_preparation_course=="none"].writing_score.mean())
print(data1[data1.test_preparation_course=="none"].writing_score.mode())
print("the average and mode of the writing score of the complete test preparation type students")
print(data1[data1.test_preparation_course=="completed"].writing_score.mean())
print(data1[data1.test_preparation_course=="completed"].writing_score.mode())
# Out:
# the average and mode of the writing score of the none test preparation type students
# 64.50467289719626
# 0    74
# dtype: int64
# the average and mode of the writing score of the complete test preparation type students
# 74.41899441340782
# 0    68
# 1    80
# dtype: int64

# %%
sns.distplot(data1[data1.test_preparation_course=="none"].writing_score,label="none",kde=True)
sns.distplot(data1[data1.test_preparation_course=="completed"].writing_score,label="completed",kde=True)
plt.title("distribution of the students writing score on the basis ofthort test preparation course")
plt.legend(labels=["none","completed"])
plt.show()

# %%
sns.boxplot(x="test_preparation_course",y="writing_score",data=data1)

# %%
#students who have completed test prearation course have scored higher in writing test than students who have not done any course

# %%
sns.boxplot(x="test_preparation_course",y="writing_score",hue="gender",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="writing_score",hue="gender",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="writing_score",hue="gender",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="writing_score",hue="race",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="writing_score",hue="race",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="writing_score",hue="race",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="writing_score",hue="parental_level_of_education",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="writing_score",hue="parental_level_of_education",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="writing_score",hue="parental_level_of_education",data=data1)

# %%
sns.boxplot(x="test_preparation_course",y="writing_score",hue="lunch",data=data1)

# %%
sns.violinplot(x="test_preparation_course",y="writing_score",hue="lunch",data=data1)

# %%
sns.scatterplot(x="test_preparation_course",y="writing_score",hue="lunch",data=data1)

# %%
# female students of grouo C and master's degree parental level of education and standard lunch have scored better in writing test
# male student of grouo E has scored highest in writing test

# %%
data1.corr()
# Out:
#                math_score  reading_score  writing_score
# math_score       1.000000       0.817580       0.802642
# reading_score    0.817580       1.000000       0.954598
# writing_score    0.802642       0.954598       1.000000

# %%
sns.heatmap(data1.corr())

# %%
sns.pairplot(data1)

# %%
#it shows how one score is affected by another
#it can be seen that as one score increases the other one also increases
